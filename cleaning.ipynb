# %%
import pandas as pd

# %%
x=pd.read_csv("loan_dirty.csv")

# %%
x
# Out:
#       loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0          2500         2500             2500   36 months     13.56
# 1         30000        30000            30000   60 months     18.94
# 2          5000         5000             5000   36 months     17.97
# 3          4000         4000             4000   36 months     18.94
# 4         30000        30000            30000   60 months     16.14
# 5          5550         5550             5550   36 months     15.02
# 6          2000         2000             2000   36 months     17.97
# 7          6000         6000             6000   36 months     13.56
# 8          5000         5000             5000   36 months     17.97
# 9          6000         6000             6000   36 months     14.47
# 10         5500         5500             5500   36 months     22.35
# 11        28000        28000            28000   60 months     11.31
# 12        11200        11200            11200   36 months      8.19
# ...

# %%
#The number of missing values in each column
x.isnull().sum()
# Out:
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
# term                     0
# int_rate                 0
# installment              0
# grade                  484
# sub_grade              484
# emp_title              902
# emp_length             459
# home_ownership         538
# annual_inc             292
# verification_status    432
# issue_d                  0
# loan_status              0
# purpose                  0
# title                    0
# zip_code                 0
# addr_state               0
# dtype: int64

# %%
#only annual income is numerical data.. we fill it up with mean
x_fill=x.fillna(x.mean())

# %%
#Now number of missing values in annual_inc is zero
x_fill.isnull().sum()
# Out:
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
# term                     0
# int_rate                 0
# installment              0
# grade                  484
# sub_grade              484
# emp_title              902
# emp_length             459
# home_ownership         538
# annual_inc               0
# verification_status    432
# issue_d                  0
# loan_status              0
# purpose                  0
# title                    0
# zip_code                 0
# addr_state               0
# dtype: int64

# %%
#filling up columns with missing categorical data values
#ffill is forward fill that fills the nan value with previous valid element
x_fill=x_fill.fillna(method="ffill")

# %%
#Now no nan values in dataset
#All null values have been suitably filled
print(x_fill.isnull().sum())
# Out:
# loan_amnt              0
# funded_amnt            0
# funded_amnt_inv        0
# term                   0
# int_rate               0
# installment            0
# grade                  0
# sub_grade              0
# emp_title              0
# emp_length             0
# home_ownership         0
# annual_inc             0
# verification_status    0
# issue_d                0
# loan_status            0
# purpose                0
# title                  0
# zip_code               0
# addr_state             0
# dtype: int64

# %%
#Saving the cleaned dataset to a new csv file called loan_clean.csv
x_fill.to_csv("loan_clean.csv")
